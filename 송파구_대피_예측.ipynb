# %% [markdown]
# <a href="https://colab.research.google.com/github/JAEKWANG97/data-analysis/blob/main/%EC%86%A1%ED%8C%8C%EA%B5%AC_%EB%8C%80%ED%94%BC_%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('서울특별시 송파구_민방위대피시설_20210914.csv',encoding='UTF-8')

# %%
df.head()
print(df)
# Out:
#         민방위대피시설명    민방위대피시설구분                               소재지도로명주소  소재지지번주소  \
# 0     2호선 종합운동장역   2호선 종합운동장역     서울특별시 송파구 올림픽로 지하 23 (잠실동, 종합운동장역)      NaN
# 1      2호선 잠실새내역    2호선 잠실새내역       서울특별시 송파구 올림픽로 지하 140 (잠실동, 신천역)      NaN
# 2        2호선 잠실역      2호선 잠실역    서울특별시 송파구 올림픽로 지하 265 (잠실동, 잠실역2호선)      NaN
# 3     잠실성당 지하강의실   잠실성당 지하강의실      서울특별시 송파구 올림픽로12길 9 (잠실동, 잠실천주교회)      NaN
# 4         잠실종합상가       잠실종합상가     서울특별시 송파구 백제고분로 157 (잠실동, 반도가구전시장)      NaN
# ..           ...          ...                                    ...      ...
# 153      9호선 삼전역      9호선 삼전역      서울특별시 송파구 백제고분로 지하 189 (잠실동, 삼전역)      NaN
# 154        석촌고분역        석촌고분역    서울특별시 송파구 백제고분로 지하 274 (삼전동, 석촌고분역)      NaN
# 155        한성백제역        한성백제역     서울특별시 송파구 위례성대로 지하 29 (방이동, 한성백제역)      NaN
# 156        송파나루역        송파나루역    서울특별시 송파구 백제고분로 지하 446 (방이동, 송파나루역)      NaN
# 157  헬리오시티 지하주차장  헬리오시티 지하주차장  서울특별시 송파구 송파대로 345, 103동 (가락동, 헬리오시티)      NaN
#
# ...

# %%
df.describe()
# Out:
#        소재지지번주소          위도          경도      민방위대피시설면적        대피가능인원수
# count      0.0  158.000000  158.000000     158.000000     158.000000
# mean       NaN   37.502710  127.118615    8635.721519   10466.664557
# std        NaN    0.012264    0.021331   40587.558071   49196.505045
# min        NaN   37.476867  127.072028     150.000000     181.000000
# 25%        NaN   37.494714  127.105034    1138.000000    1379.000000
# 50%        NaN   37.502578  127.119956    3076.500000    3728.500000
# 75%        NaN   37.510975  127.134708    7556.750000    9159.000000
# max        NaN   37.539736  127.158164  507732.000000  615432.000000

# %%
total = df['대피가능인원수'].sum()
print(total)
# Out:
# 1653733

# %%
if(1653733>667960):
  print('yes')
else:
  print('no')
print(1653733 - 667960)
#전체 수용 가능 인원 > 송파구 인구 ==> 수용 가능하다. 그렇다면 분포는 어떨까?
# Out:
# yes
# 985773

# %%
if(1653733>3290000):
  print('yes')
else:
  print('no')
# Out:
# no

# %%
df['area_per_person'] = df['민방위대피시설면적'] / df['대피가능인원수']

# %%
df.head()
df.describe()
# Out:
#        소재지지번주소          위도          경도      민방위대피시설면적        대피가능인원수  \
# count      0.0  158.000000  158.000000     158.000000     158.000000
# mean       NaN   37.502710  127.118615    8635.721519   10466.664557
# std        NaN    0.012264    0.021331   40587.558071   49196.505045
# min        NaN   37.476867  127.072028     150.000000     181.000000
# 25%        NaN   37.494714  127.105034    1138.000000    1379.000000
# 50%        NaN   37.502578  127.119956    3076.500000    3728.500000
# 75%        NaN   37.510975  127.134708    7556.750000    9159.000000
# max        NaN   37.539736  127.158164  507732.000000  615432.000000
#
#        area_per_person
# count       158.000000
# mean          0.825214
# std           0.000493
# min           0.825000
# 25%           0.825002
# 50%           0.825043
# 75%           0.825151
# max           0.828729

# %%
import pandas as pd
import folium

df = pd.read_csv('서울특별시 송파구_민방위대피시설_20210914.csv',encoding='UTF-8')

# 서울의 위도와 경도를 이용해 지도를 생성합니다.
m = folium.Map(location=[37.5665, 126.9780], zoom_start=10)

# DataFrame의 각 행에 대해 지도에 마커를 추가합니다.
for idx, row in df.iterrows():
    folium.Marker([row['위도'], row['경도']], popup=row['민방위대피시설명']).add_to(m)

# 지도를 출력합니다.
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#대피 시설의 경우 법으로 1인당 면적 0.825 m^2 으로 할당되도록 나와있다.

# %%
# 민방위사태 발생 시 주민의 생명과 재산 보호에 필수적인 주민대피시설을 넓히는 방향으로 재설계해야 한다는 제언이 제기돼 정부가 내부 검토에 돌입했다.

# 26일 당국에 따르면 행정안전부는 한국국가전략연구원(KRINS)에 의뢰해 지난해 말 제출받은 ‘주민친화형 접경지역 주민대피시설 표준공간 설계 모델개발 연구’ 결과를 검토 중에 있는 것으로 알려졌다.

# KRINS는 외교·통일·국방 분야 고위 관료와 학계 전문가들이 국가전략을 연구하고 정책을 제안하기 위해 세운 학술기관이다.

# KRINS가 제언한 연구는 북한의 위협이 계속되는 현 상황에서 필수 시설이 된 주민대피시설을 한국인의 커진 체형에 맞춰 적정 확보하면서 동시에 평상 시 활용성을 제고할 수 있도록 표준 설계모델을 제시하는 것을 골자로 한다.

# KRINS에 따르면 2021년 말 기준 전국적으로 설치된 주민대피시설은 총 1만7363개소다. 대피 용도 목적으로 혈세를 들여 설치한 ‘정부지원 대피시설’이 238개소, 민간 및 정부·지자체·공공단체 소유의 지하 시설물을 대피시설로 지정한 ‘공공용 대피시설’이 1만7125개소다.

# 현행 규정상 수용 인원 1명당 면적은 정부지원 대피시설이 1.43㎡(0.43평), 공공용 대피시설이 0.825㎡(0.25평)로 적용돼 있다. 이는 과거 한국인 평균 신장 170.6㎝를 고려해 산출한 규모다.

# 정부지원 대피시설은 성인 1명이 누워서 쉴 수 있는, 공공용 대피시설은 성인 1명이 가부좌 좌세로 앉을 수 있는 수준이다.

# 지난해 기준 한국인 평균 신장 172.5㎝, 20대 평균 신장 174.4㎝ 및 어깨넓이 43.3㎝를 각각 고려했을 때 최소한 1명당 0.99~1.75㎡(0.30~0.53평)은 돼야 한다는 게 KRINS 측 제안이다.

# 해외 사례를 비교해봐도 미국 0.89~2.8㎡, 스위스 3.30㎡, 핀란드 0.6~2.41㎡, 독일 1.98㎡를 각각 적용하고 있어 우리나라가 훨씬 협소하다.

# KRINS는 “주민의 생명과 안전에 직결된 주민대피시설 표준도면 설계는 과하다 싶을 정도로 미리 연구하고 대비해야 한다”면서 “특히 보다 현실적인 1인당 면적을 산정해 유사 시 장기간 머물 수 있는 공간으로 전면 재검토가 필요하다”고 설명했다.

# 여기에 화학·생물학·방사능 등으로부터 견딜 수 있는 방호력을 갖추면서 평상시에도 활용할 수 있도록 설계해야 한다고 제언했다.

# KRINS는 “국가 예산이 많이 투입된다는 점에서 한 번 설계할 때 올바르게 할 필요가 있다”면서 “단계적으로 중장기 계획을 세워 신설하는 주민대피시설은 창고 개념 수준의 대피소가 아닌 핵 방호와 주민 생활이 가능한 주민친화형 핵 벙커로 준비하는 것이 타당하다”고 강조했다

# 출처 : 안전저널(http://www.anjunj.com)

# %%
#해당 주민 대피 시설은 창고 개념 수준의 대피소가 아닌 핵 방호와 주민 생활이 가능한 주민 친화형 핵벙커로 준비하는 것이 타당하다는 주장에 따라 개인 면적을 넓히겠다.
#0.25평의 경우 성인 남성이

# %%
#https://github.com/raqoon886/Local_HangJeongDong 해당 깃헙에서 geoJSOn 파일 입수

# %%
import folium

# 서울의 중심 위도, 경도
center = [37.5665, 126.9780]

# 지도 생성
m = folium.Map(location=center, zoom_start=10)

# GeoJSON 데이터 로드
geo_json_data = 'hangjeongdong_서울특별시.geojson'

# GeoJSON 레이어 추가
folium.GeoJson(
    geo_json_data,
    name='Songpa'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import json

# GeoJSON 파일 열기
with open('hangjeongdong_서울특별시.geojson') as f:
    data = json.load(f)

# JSON 데이터 출력
print(data.keys())
print(data['features'][:1])  # 처음 5개의 feature만 출력
# Out:
# dict_keys(['type', 'name', 'crs', 'features'])
# ...

# %%
import folium
import json

# 서울의 중심 위도, 경도
center = [37.5665, 126.9780]

# 지도 생성
m = folium.Map(location=center, zoom_start=10)

# GeoJSON 데이터 로드
geo_json_data = 'hangjeongdong_서울특별시.geojson'

# GeoJSON 파일 열기
with open(geo_json_data) as f:
    data = json.load(f)

# Filter features for Songpa-gu
filtered_features = [feature for feature in data['features'] if feature['properties']['sggnm'] == '송파구']

# Create a new GeoJSON dictionary with filtered features
filtered_data = {
    'type': 'FeatureCollection',
    'features': filtered_features
}

# GeoJSON 레이어 추가
folium.GeoJson(
    filtered_data,
    name='Songpa'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
import folium
import json

# Load GeoJSON data
geo_json_data = 'hangjeongdong_서울특별시.geojson'
with open(geo_json_data) as f:
    data = json.load(f)

# Filter features for Songpa-gu
filtered_features = [feature for feature in data['features'] if feature['properties']['sggnm'] == '송파구']

# Create a new GeoJSON dictionary with filtered features
filtered_data = {
    'type': 'FeatureCollection',
    'features': filtered_features
}

# Load the DataFrame with marker data
df = pd.read_csv('서울특별시 송파구_민방위대피시설_20210914.csv', encoding='UTF-8')

# Create a folium map object
m = folium.Map(location=[37.5665, 126.9780], zoom_start=10)

# Add filtered GeoJSON data as a GeoJson layer
folium.GeoJson(filtered_data, name='Songpa').add_to(m)

# Add markers from DataFrame to the map
for idx, row in df.iterrows():
    folium.Marker([row['위도'], row['경도']], popup=row['민방위대피시설명']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
popular_df = pd.read_csv('송파구 동별 인구 수.csv',encoding='UTF-8')
popular_df.head()
# Out:
#               동별      계      남      여
# 0  풍납1동           12150   5971   6179
# 1  풍납2동           24057  11387  12670
# 2  거여1동           12122   6085   6037
# 3  거여2동           23701  11546  12155
# 4  마천1동           18340   9400   8940

# %%
import pandas as pd
import folium
import json

# Load GeoJSON data
geo_json_data = 'hangjeongdong_서울특별시.geojson'
with open(geo_json_data) as f:
    data = json.load(f)

# Filter features for Songpa-gu
filtered_features = [feature for feature in data['features'] if feature['properties']['sggnm'] == '송파구']

# Create a new GeoJSON dictionary with filtered features
filtered_data = {
    'type': 'FeatureCollection',
    'features': filtered_features
}

# Load the DataFrame with population data
df = pd.read_csv('송파구 동별 인구 수.csv', encoding='UTF-8')

# Create a folium map object
m = folium.Map(location=[37.5665, 126.9780], zoom_start=10)

# Add filtered GeoJSON data as a GeoJson layer
folium.GeoJson(filtered_data, name='Songpa').add_to(m)

evacuationfacility_df = pd.read_csv('서울특별시 송파구_민방위대피시설_20210914.csv',encoding='UTF-8')


# Add choropleth layer for population data
folium.Choropleth(
    geo_data=filtered_data,
    name='Population',
    data=df,
    columns=['동별', '계'],
    key_on='feature.properties.adm_nm',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Population',
).add_to(m)

# Add markers from DataFrame to the map
for idx, row in evacuationfacility_df.iterrows():
    folium.Marker([row['위도'], row['경도']], popup=row['민방위대피시설명']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
